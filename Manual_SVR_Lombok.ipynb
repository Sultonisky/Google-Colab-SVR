# %% [markdown]
# <a href="https://colab.research.google.com/github/Sultonisky/Google-Colab-SVR/blob/main/Manual_SVR_Lombok.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: pandas>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 1)) (2.2.2)
# Requirement already satisfied: numpy>=1.23.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 2)) (2.0.2)
# Requirement already satisfied: scikit-learn>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 3)) (1.6.1)
# Requirement already satisfied: matplotlib>=3.6.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 4)) (3.10.0)
# Requirement already satisfied: openpyxl>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from -r requirements.txt (line 5)) (3.1.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.5.0->-r requirements.txt (line 1)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.5.0->-r requirements.txt (line 1)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.5.0->-r requirements.txt (line 1)) (2025.3)
# Requirement already satisfied: scipy>=1.6.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.2.0->-r requirements.txt (line 3)) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.2.0->-r requirements.txt (line 3)) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn>=1.2.0->-r requirements.txt (line 3)) (3.6.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.6.0->-r requirements.txt (line 4)) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.6.0->-r requirements.txt (line 4)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.6.0->-r requirements.txt (line 4)) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.6.0->-r requirements.txt (line 4)) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.6.0->-r requirements.txt (line 4)) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.6.0->-r requirements.txt (line 4)) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.6.0->-r requirements.txt (line 4)) (3.2.5)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.12/dist-packages (from openpyxl>=3.0.0->-r requirements.txt (line 5)) (2.0.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=1.5.0->-r requirements.txt (line 1)) (1.17.0)

# %%
import os
import sys

sys.path.append("/content")

required_py = "SVR_Manual_Lombok.py"

print("[INFO] Checking for SVR_Manual_Lombok.py...")

# Check if main file exists
if os.path.exists(required_py):
    print("[SUCCESS] SVR_Manual_Lombok.py found.")
else:
    print("[WARNING] SVR_Manual_Lombok.py not found. Searching for similar filenames...")

    # Find alternative files such as SVR_Manual_Lombok (1).py or similar
    for f in os.listdir("/content"):
        if f.startswith("SVR_Manual_Lombok") and f.endswith(".py") and f != required_py:
            os.rename(f, required_py)
            print("[INFO] Similar Python file found and renamed to SVR_Manual_Lombok.py")
            break
    else:
        print("[ERROR] No matching Python file found. Please ensure the file has been uploaded to Colab.")
# Out:
# [INFO] Checking for SVR_Manual_Lombok.py...
# [SUCCESS] SVR_Manual_Lombok.py found.

# %%
import importlib.util

spec = importlib.util.spec_from_file_location("SVR_Manual_Lombok", "SVR_Manual_Lombok.py")
mod = importlib.util.module_from_spec(spec)
spec.loader.exec_module(mod)

SVRForecasting = mod.SVRForecasting

file_path = "dataset_lombok_2017_2025.xlsx"
forecaster = SVRForecasting(file_path)

# Load data sheet pertama
if not forecaster.load_data(sheet_name=1):
    raise SystemExit("Failed to load data")

# Parameter manual
w1, w2, b = 0.01152, -0.000843, 0.02091

calculation_ok = forecaster.calculate_manual_svr(
    rooms_sold_col=None,
    rooms_available_col=None,
    w1=w1, w2=w2, b=b,
    output_col="X",
    n_rows=10
)

if calculation_ok:
    forecaster.explain_svr_calculation()
    # Simpan dataset dengan kolom X
    from datetime import datetime
    ts = datetime.now().strftime("%Y%m%d_%H%M%S")
    output_file = f"dataset_lombok_with_svr_{ts}.xlsx"
    forecaster.data.to_excel(output_file, index=False)
    print(f"[SUCCESS] Saved {output_file}")
# Out:
# ============================================================
# STEP 1: MEMUAT DATA DARI FILE EXCEL
# ============================================================
#
# [SUCCESS] Data loaded successfully!
# Number of rows: 3000
# Number of columns: 27
#
# Data preview:
#    date_time  year  month  day  dayofweek  is_weekend  season  \
# 0 2023-01-01  2023      1    1          7           1       3
# 1 2023-01-02  2023      1    2          1           0       3
# 2 2023-01-03  2023      1    3          2           0       3
# 3 2023-01-04  2023      1    4          3           0       3
# 4 2023-01-05  2023      1    5          4           0       3
#
#               nama_hotel  lead_time  stays_in_week_nights  ...  \
# 0      Pullman Mandalika         28                     2  ...
# 1  Kuta Mandalika Resort         37                     1  ...
# 2   Senggigi Beach Hotel         58                     1  ...
# 3      Pullman Mandalika         20                     0  ...
# 4      Vila Ombak Gili T         19                     3  ...
#
#    holiday_school  holiday_natal_newyear  holiday_or_event  rooms_sold  \
# 0               0                      1                 1          93
# 1               0                      1                 1          81
# 2               0                      1                 1          54
# 3               0                      1                 1          48
# 4               0                      1                 1          29
#
#    rooms_available  occupancy_rate  prediksi_svr  awareness  importance  \
# 0              120           77.50         78.20       4.06        3.96
# 1              150           54.00         56.53       4.06        3.96
# 2               80           67.50         67.86       4.06        3.96
# 3              120           40.00         39.91       4.06        3.96
# 4               80           36.25         38.31       4.06        3.96
#
#    tech_trust
# 0       4.048
# 1       4.048
# 2       4.048
# 3       4.048
# 4       4.048
#
# [5 rows x 27 columns]
#
# Data info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 27 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   date_time                3000 non-null   datetime64[ns]
#  1   year                     3000 non-null   int64
#  2   month                    3000 non-null   int64
#  3   day                      3000 non-null   int64
#  4   dayofweek                3000 non-null   int64
#  5   is_weekend               3000 non-null   int64
#  6   season                   3000 non-null   int64
#  7   nama_hotel               3000 non-null   object
#  8   lead_time                3000 non-null   int64
#  9   stays_in_week_nights     3000 non-null   int64
#  10  stays_in_weekend_nights  3000 non-null   int64
#  11  adults                   3000 non-null   int64
#  12  children                 3000 non-null   int64
#  13  days_in_waiting_list     3000 non-null   int64
#  14  holiday_nyepi            3000 non-null   int64
#  15  holiday_galungan         3000 non-null   int64
#  16  holiday_kuningan         3000 non-null   int64
#  17  holiday_school           3000 non-null   int64
#  18  holiday_natal_newyear    3000 non-null   int64
#  19  holiday_or_event         3000 non-null   int64
#  20  rooms_sold               3000 non-null   int64
#  21  rooms_available          3000 non-null   int64
#  22  occupancy_rate           3000 non-null   float64
#  23  prediksi_svr             3000 non-null   float64
#  24  awareness                3000 non-null   float64
#  25  importance               3000 non-null   float64
#  26  tech_trust               3000 non-null   float64
# dtypes: datetime64[ns](1), float64(5), int64(20), object(1)
# memory usage: 632.9+ KB
# None
#
# Descriptive statistics:
#                  date_time         year        month          day  \
# count                 3000  3000.000000  3000.000000  3000.000000
# mean   2027-02-08 12:00:00  2026.616667     6.401333    15.684667
# min    2023-01-01 00:00:00  2023.000000     1.000000     1.000000
# 25%    2025-01-19 18:00:00  2025.000000     3.000000     8.000000
# 50%    2027-02-08 12:00:00  2027.000000     6.000000    16.000000
# 75%    2029-02-27 06:00:00  2029.000000     9.000000    23.000000
# max    2031-03-19 00:00:00  2031.000000    12.000000    31.000000
# std                    NaN     2.372256     3.486878     8.792061
#
#          dayofweek   is_weekend       season    lead_time  \
# count  3000.000000  3000.000000  3000.000000  3000.000000
# mean      3.999000     0.285667     1.928000    29.819000
# min       1.000000     0.000000     1.000000     0.000000
# 25%       2.000000     0.000000     1.000000    15.000000
# 50%       4.000000     0.000000     2.000000    30.000000
# 75%       6.000000     1.000000     3.000000    45.000000
# max       7.000000     1.000000     3.000000    59.000000
# std       2.000917     0.451807     0.802723    17.331389
#
#        stays_in_week_nights  stays_in_weekend_nights  ...  holiday_school  \
# count           3000.000000              3000.000000  ...     3000.000000
# mean               2.000000                 0.986000  ...        0.245333
# min                0.000000                 0.000000  ...        0.000000
# 25%                1.000000                 0.000000  ...        0.000000
# 50%                2.000000                 1.000000  ...        0.000000
# 75%                3.000000                 2.000000  ...        0.000000
# max                4.000000                 2.000000  ...        1.000000
# std                1.414685                 0.827062  ...        0.430356
#
#        holiday_natal_newyear  holiday_or_event   rooms_sold  rooms_available  \
# count            3000.000000       3000.000000  3000.000000      3000.000000
# mean                0.047000          0.288667    75.453667       112.486667
# min                 0.000000          0.000000    28.000000        80.000000
# 25%                 0.000000          0.000000    54.000000       100.000000
# 50%                 0.000000          0.000000    71.000000       100.000000
# 75%                 0.000000          1.000000    94.000000       120.000000
# max                 1.000000          1.000000   150.000000       150.000000
# std                 0.211674          0.453218    28.029159        25.750810
#
#        occupancy_rate  prediksi_svr     awareness    importance    tech_trust
# count     3000.000000   3000.000000  3.000000e+03  3.000000e+03  3.000000e+03
# mean        67.034793     67.035600  4.060000e+00  3.960000e+00  4.048000e+00
# min         34.670000     29.350000  4.060000e+00  3.960000e+00  4.048000e+00
# 25%         50.670000     50.770000  4.060000e+00  3.960000e+00  4.048000e+00
# 50%         66.670000     66.970000  4.060000e+00  3.960000e+00  4.048000e+00
# 75%         83.330000     83.435000  4.060000e+00  3.960000e+00  4.048000e+00
# max        100.000000    106.330000  4.060000e+00  3.960000e+00  4.048000e+00
# std         18.997862     19.116113  4.708130e-14  2.478431e-13  1.083758e-13
#
# [8 rows x 26 columns]
#
# ============================================================
# PERHITUNGAN MANUAL SVR DENGAN KERNEL LINEAR
# ============================================================
#
# Columns used:
#   rooms_sold: 'rooms_sold'
#   rooms_available: 'rooms_available'
#
# Linear SVR Formula:
#   y = w1 * rooms_sold + w2 * rooms_available + b
#
# Parameters:
#   w1 (rooms_sold weight)     = 0.01152
#   w2 (rooms_available weight) = -0.000843
#   b (bias/intercept)         = 0.02091
#
# ============================================================
# STEP-BY-STEP CALCULATION (FIRST 10 ROWS)
# ============================================================
#
# No    rooms_sold      rooms_available      Calculation                              Result (X)
# -----------------------------------------------------------------------------------------------
# 1     93.00           120.00               0.01152 × 93.00 + -0.000843 × 120.00 + 0.02091 0.991110
# 2     81.00           150.00               0.01152 × 81.00 + -0.000843 × 150.00 + 0.02091 0.827580
# 3     54.00           80.00                0.01152 × 54.00 + -0.000843 × 80.00 + 0.02091 0.575550
# 4     48.00           120.00               0.01152 × 48.00 + -0.000843 × 120.00 + 0.02091 0.472710
# 5     29.00           80.00                0.01152 × 29.00 + -0.000843 × 80.00 + 0.02091 0.287550
# 6     97.00           100.00               0.01152 × 97.00 + -0.000843 × 100.00 + 0.02091 1.054050
# 7     133.00          150.00               0.01152 × 133.00 + -0.000843 × 150.00 + 0.02091 1.426620
# 8     49.00           120.00               0.01152 × 49.00 + -0.000843 × 120.00 + 0.02091 0.484230
# 9     63.00           150.00               0.01152 × 63.00 + -0.000843 × 150.00 + 0.02091 0.620220
# 10    48.00           100.00               0.01152 × 48.00 + -0.000843 × 100.00 + 0.02091 0.489570
#
# ... (total 3000 baris)
#
# ============================================================
# MANUAL SVR CALCULATION SUMMARY
# ============================================================
# Total rows calculated: 3000
# Minimum value: 0.276030
# Maximum value: 1.622460
# Average value: 0.795310
# Standard deviation: 0.309792
#
# [SUCCESS] Results saved to column 'X' in dataframe!
#
# ============================================================
# PENJELASAN PERHITUNGAN SVR (SUPPORT VECTOR REGRESSION)
# ============================================================
#
# 1) Rumus inti (kernel linear)
#    y = (w1 * rooms_sold) + (w2 * rooms_available) + b
#    Dipakai apa adanya (tanpa scaling) sesuai parameter yang diberikan.
#
# 2) Parameter yang digunakan
#    - w1 = 0.01152   → pengaruh rooms_sold (positif)
#    - w2 = -0.000843 → pengaruh rooms_available (negatif)
#    - b  = 0.02091   → bias/intercept (baseline saat fitur = 0)
#
# 3) Contoh perhitungan (langkah eksplisit)
#    Misal rooms_sold = 100, rooms_available = 200:
#    a. Kontribusi rooms_sold:      0.01152 * 100  = 1.15200
#    b. Kontribusi rooms_available: -0.000843 * 200 = -0.16860
#    c. Tambahkan bias:             +0.02091
#    d. Total: y = 1.15200 - 0.16860 + 0.02091 = 1.00431
#
# 4) Interpretasi cepat
#    - w1 positif: rooms_sold naik → prediksi naik.
#    - w2 negatif: rooms_available naik → prediksi turun (lebih banyak kamar kosong).
#    - b sebagai baseline jika semua fitur 0; pada data nyata y bergantung pada skala fitur.
#
# 5) Kenapa linear?
#    - Asumsi hubungan cukup linear, perhitungan cepat, mudah dijelaskan, dan selaras dengan parameter yang sudah ditetapkan.
#
#
# ============================================================
# [SUCCESS] Saved dataset_lombok_with_svr_20260110_170426.xlsx
#
# ============================================================
# GAP ANALYSIS: 'prediksi_svr' (Excel) vs 'X' (Program)
# ============================================================
#
# [SUCCESS] Gap analysis results saved to 'gap_prediksi_svr_vs_X_Lombok.xlsx'
#
# [SUMMARY] Gap Analysis Summary:
#    Minimum Gap: -104.719060
#    Maximum Gap: -28.923370
#    Average Gap: -66.240290
#    Standard Deviation of Gap: 18.867462
#
# [PREVIEW] Gap Analysis Results (first 5 rows):
#  Periode  prediksi_svr       X       Gap  Gap_Absolute  Gap_Percentage
#        0         78.20 0.99111 -77.20889      77.20889      -98.732596
#        1         56.53 0.82758 -55.70242      55.70242      -98.536034
#        2         67.86 0.57555 -67.28445      67.28445      -99.151857
#        3         39.91 0.47271 -39.43729      39.43729      -98.815560
#        4         38.31 0.28755 -38.02245      38.02245      -99.249413

# %%
from google.colab import files
if calculation_ok:
    forecaster.explain_svr_calculation()

    # Simpan visualisasi manual SVR
    forecaster.visualize_manual_svr_results(
        x_col="X",
        rooms_sold_col=None,
        rooms_available_col=None
    )

    # Auto-download hasil visualisasi
    # Correcting the file path to match where the visualization was actually saved.
    files.download("/result/img/SVR_Manual_Bali_visualization.png")
# Out:
# [SUCCESS] Downloaded dataset_lombok_with_svr_20260110_170426.xlsx
# [SUCCESS] Downloaded gap_prediksi_svr_vs_X_Lombok.xlsx
